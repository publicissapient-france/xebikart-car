# %% [markdown]
# # **<center>Using CNN to predict angles and throttles<center>**
#
# In this notebook, you can download images obtained with the donkey car. You can use them to launch a training in order to get a model for the donkey car.
# Several options are available :
#
# - The number of image to learn from
# - The possibility to invert them to also learn turning right

# %%
import json
import shutil
import random
import pathlib
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import IPython.display as display

import mlflow
import mlflow.tensorflow
import mlflow.keras

import tensorflow as tf

from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.metrics import MSLE, MAE, MSE
from tensorflow.keras.losses import MSE, MSLE
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

from xebikart.images import transformer as T
import xebikart.dataset as dataset

from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
tf.__version__
# Out:
# '1.14.0'

# %%
tf.test.is_gpu_available()
# Out:
# False

# %% [markdown]
# Eager Execution allows to evaluate operations immediately without building graphs
# note : Only needed when not using TF 2.0

# %%
tf.enable_eager_execution()

# %%
# !ls
# Out:
# CNN.ipynb  CNN_learn_turning_right.ipynb  RTR.ipynb  workspace

# %%
# parameters
# dataset parameters
tubes_root_folder = "file:/workspace/xebikart-ml-tubes"
tubes_folders = [
    #"tub.v4.01",
    #"tub.v4.02",
    #"tub.v4.03",
    "tub.v5.01"
]
test_size=0.2

# training parameters
batch_size = 32
shuffle_size = 200
n_epochs = 50
learning_rate = 1e-4

# %% [markdown]
# # Load data

# %% [markdown]
# Download tubes from : https://github.com/xebia-france/xebikart-ml-tubes

# %%
raw_tubes_df = dataset.get_tubes_df(tubes_root_folder, tubes_folders, tubes_extension=".tar.gz")
tubes_df = raw_tubes_df.rename(columns={"cam/image_array": "images_path", "user/angle": "angles", "user/throttle": "throttles"})
tubes_df.count()
# Out:
# timestamp      1028
# images_path    1028
# user/mode      1028
# angles         1028
# throttles      1028
# dtype: int64

# %% [markdown]
# #### **- Display some examples**

# %%
fig, axs = plt.subplots(1, 3, figsize=(15,5), constrained_layout=True)
fig.suptitle("Angle / Throttle", fontsize=20)

for n, sample in tubes_df.sample(3).reset_index().iterrows():
    random_image_path = sample["images_path"]
    angle = sample["angles"]
    throttle = sample["throttles"]
    image = mpimg.imread(random_image_path) 
    axs[n].set_title(f"{angle} / {throttle}")
    axs[n].imshow(image)
    axs[n].get_xaxis().set_visible(False)
    axs[n].get_yaxis().set_visible(False)

# %% [markdown]
# #### **- Display some sample distribution**

# %%
fig, axs = plt.subplots(1,2, figsize=(15,5))
axs[0].hist(tubes_df.angles)
axs[0].set_title('distribution angles')
axs[1].hist(tubes_df.throttles)
axs[1].set_title('distribution throttles')

plt.show()

# %% [markdown]
# # Preprocessing Images

# %% [markdown]
# **Images will be :**
# - Loaded
#     - Read images
#     - Decode jpeg images into uint8 tensor
# - Cropped
#     - Crop images on the lower part
# - Augmented
#     - Brightness : Adjust the brightness of images by a random factor.
#     - Saturation : Adjust the saturation of images by a random factor (must be RGB images)
#     - Contrast : Adjust the contrast of images by a random factor.
#     - Jpeg quality : Randomly changes jpeg encoding quality for inducing jpeg noise
# - Normalized
#     - Image are converted into Float32 between 0 and 1
# - Edged
#     - Convert tensor uint8 type into float32 type
#     - Convert rgb images to grayscale
#     - Reshape into [1, 80, 160, 1] tensor
#     - Apply sobel filter (see https://en.wikipedia.org/wiki/Sobel_operator)
#     - Reshape into [80, 160, 2] tensor
#     - Select image gradient up to 0.3
#     - Binarize images by setting elements to 0 or 1

# %%
crop_fn = T.generate_crop_fn(left_margin=0, width=160, height_margin=40, height=80)

def load_augmentation_preprocess(image_path):
    tf_image = T.read_image(image_path)
    tf_image = T.normalize(tf_image)
    tf_image = crop_fn(tf_image)
    tf_image = T.data_augmentation(tf_image)
    tf_image = T.edges(tf_image)
    return tf_image

# %% [markdown]
# ##### **- Generation of the same dataset but flip_left_right and label inversed**

# %%
def learn_to_turn_right(image_path):
    
    tf_image = T.read_image(image_path)
    tf_image = tf.image.flip_left_right(tf_image)
    tf_image = T.normalize(tf_image)
    tf_image = crop_fn(tf_image)
    tf_image = T.data_augmentation(tf_image)
    tf_image = T.edges(tf_image)
    
    return tf_image

# %% [markdown]
# ##### **- Display some examples before and after preprocessing**

# %%
random_image_path = tubes_df.sample()["images_path"].values[0]

tf_image_original   = T.read_image(random_image_path)
tf_image_cropped    = crop_fn(tf_image_original)
tf_image_augmented  = T.data_augmentation(tf_image_cropped)
tf_image_normalized = T.normalize(tf_image_augmented)
tf_image_edged      = T.edges(tf_image_normalized)

fig, axs = plt.subplots(1, 5, figsize=(15,15), constrained_layout=True)
axs[0].set_title("Original")
axs[0].imshow(tf_image_original)
axs[1].set_title("Cropping")
axs[1].imshow(tf_image_cropped)
axs[2].set_title("Augmented")
axs[2].imshow(tf_image_augmented)
axs[3].set_title("Preprocessed channel 1")
axs[3].imshow(tf_image_edged[:,:,0],cmap='gray')
axs[4].set_title("Preprocessed channel 2")
axs[4].imshow(tf_image_edged[:,:,1],cmap='gray')
plt.show()

# %% [markdown]
# # Build a dataset of images

# %% [markdown]
# #### **- Split data into test/train datasets**

# %% [markdown]
# Here you can choose label that you want to predict : Angles, Throttles or both

# %%
tubes_df['angles_throttles'] = tubes_df.apply(lambda x: list([x['angles'], x['throttles']]), axis=1)

prediction = 'angles'

images_path = tubes_df["images_path"].tolist()
metas = tubes_df[prediction].tolist()

# %%
train_images_path, test_images_path, train_metas, test_metas = train_test_split(images_path, metas, test_size=test_size)
print('Train set :', len(train_images_path), 'images')
print('Test set :', len(test_images_path), 'images')
# Out:
# Train set : 822 images
# Test set : 206 images

# %% [markdown]
# #### **- Create tensor for train and test datasets**

# %%
def input_fn(filepath, label, BATCH_SIZE = 32, SHUFFLE_SIZE = 200, NUM_EPOCHS = 200, learn_right=False):
    ds_x = tf.data.Dataset.from_tensor_slices(filepath)
    ds_x = ds_x.map(load_augmentation_preprocess)
    ds_y = tf.data.Dataset.from_tensor_slices(label)
    
    if learn_right:
        label_inversed = [n_label * -1 for n_label in label]
        ds_x_right = tf.data.Dataset.from_tensor_slices(filepath)
        ds_x_right = ds_x_right.map(learn_to_turn_right)
        ds_y_right = tf.data.Dataset.from_tensor_slices(label_inversed)
        
        ds_x = ds_x.concatenate(ds_x_right)
        ds_y = ds_y.concatenate(ds_y_right)
        
    ds_x_y = tf.data.Dataset.zip((ds_x, ds_y)).shuffle(SHUFFLE_SIZE).repeat(NUM_EPOCHS).batch(BATCH_SIZE).prefetch(1)
    
    return ds_x_y

# %%
ds_train = input_fn(train_images_path, train_metas, learn_right=True)
ds_test = input_fn(test_images_path, test_metas, learn_right=True)

# %% [markdown]
# # Build Model

# %%
model = Sequential()

model.add(Conv2D(16, (5,5), activation='relu', kernel_regularizer=l1_l2(l1=0.1, l2=0.01), input_shape=(80, 160, 2)))
model.add(MaxPooling2D(3,3))
model.add(Conv2D(32, (3,3), activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)))
model.add(MaxPooling2D(3,3))
model.add(Conv2D(64, (3,3), activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(2, activation='linear'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 76, 156, 16)       816
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 25, 52, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 23, 50, 32)        4640
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 16, 32)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 5, 14, 64)         18496
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4480)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               1147136
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 1,212,370
# Trainable params: 1,212,370
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=learning_rate, decay=1e-6), 
              loss="mean_squared_error",
              #metrics=[MAE, MSLE, MSE]
             )

# %% [markdown]
# **- How to choose and interpret loss :**
#
# Mean Absolute Error (MAE) is the absolute value of the substraction of predicted from actual value
# Let's see an example :
# Actual angle = 0.21

# %%
mlflow.set_experiment("convolutional_neural_network")

with mlflow.start_run():
    mlflow.log_params({
        'learn_right' : True,
        "images": str(tubes_folders),
        "nb_images": len(train_images_path),
        "epochs": n_epochs,
        "batch_size": batch_size,
        "learning_rate": learning_rate,
        "prediction": prediction
    })
    mlflow.tensorflow.autolog()
    history = model.fit(x=ds_train,
                    steps_per_epoch=len(train_metas)//batch_size,
                    epochs=n_epochs,
                    verbose=1,
                    validation_data=ds_test,
                    validation_steps=len(test_metas)//batch_size)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 5s 209ms/step - loss: 16.0943 - val_loss: 15.6054
# Epoch 2/50
# 25/25 [==============================] - 4s 146ms/step - loss: 15.3707 - val_loss: 14.8250
# Epoch 3/50
# 25/25 [==============================] - 4s 146ms/step - loss: 14.6162 - val_loss: 14.0788
# Epoch 4/50
# 25/25 [==============================] - 4s 146ms/step - loss: 13.8380 - val_loss: 13.3356
# Epoch 5/50
# 25/25 [==============================] - 4s 149ms/step - loss: 13.1501 - val_loss: 12.6010
# Epoch 6/50
# 25/25 [==============================] - 4s 150ms/step - loss: 12.3613 - val_loss: 11.9577
# Epoch 7/50
# 25/25 [==============================] - 4s 153ms/step - loss: 11.7503 - val_loss: 11.2806
# Epoch 8/50
# 25/25 [==============================] - 4s 149ms/step - loss: 11.0536 - val_loss: 10.6467
# Epoch 9/50
# 25/25 [==============================] - 4s 150ms/step - loss: 10.4400 - val_loss: 10.0331
# Epoch 10/50
# 25/25 [==============================] - 4s 152ms/step - loss: 9.8467 - val_loss: 9.4548
# Epoch 11/50
# 25/25 [==============================] - 4s 156ms/step - loss: 9.3079 - val_loss: 8.8776
# Epoch 12/50
# 25/25 [==============================] - 4s 151ms/step - loss: 8.7245 - val_loss: 8.3548
# Epoch 13/50
# 25/25 [==============================] - 4s 150ms/step - loss: 8.2134 - val_loss: 7.8236
# Epoch 14/50
# 25/25 [==============================] - 4s 153ms/step - loss: 7.6835 - val_loss: 7.3264
# Epoch 15/50
# 25/25 [==============================] - 4s 154ms/step - loss: 7.2013 - val_loss: 6.8414
# Epoch 16/50
# 25/25 [==============================] - 4s 150ms/step - loss: 6.7271 - val_loss: 6.3893
# Epoch 17/50
# 25/25 [==============================] - 4s 152ms/step - loss: 6.2729 - val_loss: 5.9494
# Epoch 18/50
# 25/25 [==============================] - 4s 151ms/step - loss: 5.8394 - val_loss: 5.5255
# Epoch 19/50
# 25/25 [==============================] - 4s 152ms/step - loss: 5.4249 - val_loss: 5.1119
# Epoch 20/50
# 25/25 [==============================] - 4s 163ms/step - loss: 5.0339 - val_loss: 4.7267
# Epoch 21/50
# 25/25 [==============================] - 4s 159ms/step - loss: 4.6366 - val_loss: 4.3558
# Epoch 22/50
# 25/25 [==============================] - 4s 168ms/step - loss: 4.2929 - val_loss: 4.0165
# Epoch 23/50
# 25/25 [==============================] - 4s 168ms/step - loss: 3.9593 - val_loss: 3.6869
# Epoch 24/50
# 25/25 [==============================] - 4s 159ms/step - loss: 3.6259 - val_loss: 3.3669
# Epoch 25/50
# 25/25 [==============================] - 4s 159ms/step - loss: 3.3124 - val_loss: 3.0759
# Epoch 26/50
# 25/25 [==============================] - 4s 160ms/step - loss: 3.0491 - val_loss: 2.7977
# Epoch 27/50
# 25/25 [==============================] - 4s 157ms/step - loss: 2.7699 - val_loss: 2.5465
# Epoch 28/50
# 25/25 [==============================] - 4s 156ms/step - loss: 2.5260 - val_loss: 2.2885
# Epoch 29/50
# 25/25 [==============================] - 4s 158ms/step - loss: 2.2720 - val_loss: 2.0725
# Epoch 30/50
# 25/25 [==============================] - 4s 159ms/step - loss: 2.0714 - val_loss: 1.8569
# Epoch 31/50
# 25/25 [==============================] - 4s 154ms/step - loss: 1.8536 - val_loss: 1.6853
# Epoch 32/50
# 25/25 [==============================] - 4s 155ms/step - loss: 1.6906 - val_loss: 1.4949
# Epoch 33/50
# 25/25 [==============================] - 4s 156ms/step - loss: 1.5137 - val_loss: 1.3483
# Epoch 34/50
# 25/25 [==============================] - 4s 157ms/step - loss: 1.3795 - val_loss: 1.2013
# Epoch 35/50
# 25/25 [==============================] - 4s 156ms/step - loss: 1.2182 - val_loss: 1.0959
# Epoch 36/50
# 25/25 [==============================] - 4s 158ms/step - loss: 1.1246 - val_loss: 0.9689
# Epoch 37/50
# 25/25 [==============================] - 4s 161ms/step - loss: 0.9967 - val_loss: 0.8752
# Epoch 38/50
# 25/25 [==============================] - 4s 153ms/step - loss: 0.9316 - val_loss: 0.7759
# Epoch 39/50
# 25/25 [==============================] - 4s 153ms/step - loss: 0.8211 - val_loss: 0.6956
# Epoch 40/50
# 25/25 [==============================] - 4s 153ms/step - loss: 0.7564 - val_loss: 0.6165
# Epoch 41/50
# 25/25 [==============================] - 4s 157ms/step - loss: 0.6651 - val_loss: 0.5700
# Epoch 42/50
# 25/25 [==============================] - 4s 155ms/step - loss: 0.6303 - val_loss: 0.5077
# Epoch 43/50
# 25/25 [==============================] - 4s 157ms/step - loss: 0.5604 - val_loss: 0.4512
# Epoch 44/50
# 25/25 [==============================] - 4s 158ms/step - loss: 0.5259 - val_loss: 0.4102
# Epoch 45/50
# 25/25 [==============================] - 4s 160ms/step - loss: 0.4799 - val_loss: 0.3799
# Epoch 46/50
# 25/25 [==============================] - 4s 157ms/step - loss: 0.4534 - val_loss: 0.3499
# Epoch 47/50
# 25/25 [==============================] - 4s 156ms/step - loss: 0.4238 - val_loss: 0.3288
# Epoch 48/50
# 25/25 [==============================] - 4s 154ms/step - loss: 0.4325 - val_loss: 0.3082
# Epoch 49/50
# 25/25 [==============================] - 4s 157ms/step - loss: 0.3867 - val_loss: 0.3035
# Epoch 50/50
# 25/25 [==============================] - 4s 160ms/step - loss: 0.3866 - val_loss: 0.2853

# %%
# load model
# cnn_model = mlflow.keras.load_model("runs:/5d890004534c44f1880a0da3011c80d0/model")

# %% [markdown]
# # Plot loss

# %%
def plot_results(history):
    hist_df = pd.DataFrame(history.history)
    hist_df.columns=['loss','val_loss']
    hist_df.index = np.arange(1, len(hist_df)+1)
    fig = plt.figure(figsize=(10,5))
    plt.plot(hist_df.val_loss, lw=3, label='Validation Loss')
    plt.plot(hist_df.loss, lw=3, label='Training Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.grid()
    plt.legend(loc=0)

    plt.show()

# %%
plot_results(history)

# %% [markdown]
# # Evaluation

# %% [markdown]
# **- steps:** Total number of steps (batches of samples) before declaring the prediction round finished. Ignored with the default value of None. If x is a tf.data dataset or a dataset iterator, and steps is None, predict will run until the input dataset is exhausted.

# %%
train_angles = model.predict(ds_test, steps=len(metas)//batch_size)

# %%
df = pd.DataFrame(train_angles, columns = ['angles'])
plt.figure(figsize=(10,5))
plt.title('Prediction angles')
plt.hist(df.angles)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1676                 blocks = [
# -> 1677                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1678                 ]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3264
# -> 3265     return klass(values, ndim=ndim, placement=placement)
#    3266
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     127                 "Wrong number of items passed {val}, placement implies "
# --> 128                 "{mgr}".format(val=len(self.values), mgr=len(self.mgr_locs))
#     129             )
#
# ValueError: Wrong number of items passed 2, placement implies 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-e3858e5b6933> in <module>
# ----> 1 df = pd.DataFrame(train_angles, columns = ['angles'])
#       2 plt.figure(figsize=(10,5))
#       3 plt.title('Prediction angles')
#       4 plt.hist(df.angles)
#       5 plt.show()
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     437                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     438             else:
# --> 439                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     440
#     441         # For data is list-like, or Iterable (will consume into list)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     211         block_values = [values]
#     212
# --> 213     return create_block_manager_from_blocks(block_values, [columns, index])
#     214
#     215
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1685         blocks = [getattr(b, "values", b) for b in blocks]
#    1686         tot_items = sum(b.shape[0] for b in blocks)
# -> 1687         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1688
#    1689
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals/managers.py in construction_error(tot_items, block_shape, axes, e)
#    1716         raise ValueError("Empty data passed with indices specified.")
#    1717     raise ValueError(
# -> 1718         "Shape of passed values is {0}, indices imply {1}".format(passed, implied)
#    1719     )
#    1720
#
# ValueError: Shape of passed values is (1024, 2), indices imply (1024, 1)

# %%
df.angles.plot.kde()
